# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
url = 'http://storage.googleapis.com/download.tensorflow.org/data/ecg.csv'
df = pd.read_csv(url, header=None)
raw = df.values
data = raw[:, :-1]   # signals
labels = raw[:, -1]  # 1=normal, 0=abnormal :contentReference[oaicite:3]{index=3}

data = (data - data.min())/(data.max() - data.min())

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4998 entries, 0 to 4997
# Columns: 141 entries, 0 to 140
# dtypes: float64(141)
# memory usage: 5.4 MB

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
X_train_norm = X_train[y_train==1]
X_test_norm = X_test[y_test==1]
X_test_abn = X_test[y_test==0]

input_dim = X_train_norm.shape[1]

# %%
inp = layers.Input(shape=(input_dim,))
x = layers.Dense(64, activation='relu')(inp)
x = layers.Dense(32, activation='relu')(x)
latent = layers.Dense(16, activation='relu')(x)

# %%
x = layers.Dense(32, activation='relu')(latent)
x = layers.Dense(64, activation='relu')(x)
out = layers.Dense(input_dim, activation='sigmoid')(x)

# %%
autoencoder = models.Model(inputs=inp, outputs=out)

# %%
autoencoder.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
history = autoencoder.fit(
    X_train_norm, X_train_norm,
    epochs=30,
    batch_size=64,
    validation_split=0.1,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/30
# 33/33 - 4s - 108ms/step - loss: 0.0043 - mae: 0.0416 - val_loss: 0.0029 - val_mae: 0.0326
# Epoch 2/30
# 33/33 - 0s - 7ms/step - loss: 0.0018 - mae: 0.0254 - val_loss: 0.0012 - val_mae: 0.0210
# Epoch 3/30
# 33/33 - 0s - 7ms/step - loss: 0.0010 - mae: 0.0199 - val_loss: 9.8878e-04 - val_mae: 0.0195
# Epoch 4/30
# 33/33 - 0s - 7ms/step - loss: 9.6788e-04 - mae: 0.0193 - val_loss: 9.6466e-04 - val_mae: 0.0192
# Epoch 5/30
# 33/33 - 0s - 7ms/step - loss: 9.3935e-04 - mae: 0.0190 - val_loss: 9.1658e-04 - val_mae: 0.0187
# Epoch 6/30
# 33/33 - 0s - 6ms/step - loss: 8.7524e-04 - mae: 0.0182 - val_loss: 8.2839e-04 - val_mae: 0.0178
# Epoch 7/30
# 33/33 - 0s - 7ms/step - loss: 7.8058e-04 - mae: 0.0172 - val_loss: 7.1967e-04 - val_mae: 0.0165
# Epoch 8/30
# 33/33 - 0s - 8ms/step - loss: 6.9436e-04 - mae: 0.0164 - val_loss: 6.5055e-04 - val_mae: 0.0157
# Epoch 9/30
# 33/33 - 0s - 7ms/step - loss: 6.3333e-04 - mae: 0.0157 - val_loss: 6.1124e-04 - val_mae: 0.0153
# Epoch 10/30
# 33/33 - 0s - 7ms/step - loss: 5.9385e-04 - mae: 0.0153 - val_loss: 5.6143e-04 - val_mae: 0.0149
# Epoch 11/30
# 33/33 - 0s - 7ms/step - loss: 5.3244e-04 - mae: 0.0145 - val_loss: 5.0475e-04 - val_mae: 0.0143
# Epoch 12/30
# 33/33 - 0s - 7ms/step - loss: 4.8915e-04 - mae: 0.0140 - val_loss: 4.7299e-04 - val_mae: 0.0137
# Epoch 13/30
# 33/33 - 0s - 7ms/step - loss: 4.6706e-04 - mae: 0.0136 - val_loss: 4.5912e-04 - val_mae: 0.0134
# Epoch 14/30
# 33/33 - 0s - 7ms/step - loss: 4.6137e-04 - mae: 0.0135 - val_loss: 4.5464e-04 - val_mae: 0.0134
# Epoch 15/30
# 33/33 - 0s - 7ms/step - loss: 4.5595e-04 - mae: 0.0134 - val_loss: 4.5182e-04 - val_mae: 0.0133
# Epoch 16/30
# 33/33 - 0s - 6ms/step - loss: 4.5321e-04 - mae: 0.0134 - val_loss: 4.4981e-04 - val_mae: 0.0133
# Epoch 17/30
# 33/33 - 0s - 7ms/step - loss: 4.4952e-04 - mae: 0.0133 - val_loss: 4.5099e-04 - val_mae: 0.0135
# Epoch 18/30
# 33/33 - 0s - 7ms/step - loss: 4.4911e-04 - mae: 0.0134 - val_loss: 4.4581e-04 - val_mae: 0.0132
# Epoch 19/30
# 33/33 - 0s - 8ms/step - loss: 4.4581e-04 - mae: 0.0133 - val_loss: 4.4340e-04 - val_mae: 0.0132
# Epoch 20/30
# 33/33 - 0s - 7ms/step - loss: 4.4276e-04 - mae: 0.0133 - val_loss: 4.3715e-04 - val_mae: 0.0131
# Epoch 21/30
# 33/33 - 0s - 7ms/step - loss: 4.3676e-04 - mae: 0.0131 - val_loss: 4.3805e-04 - val_mae: 0.0133
# Epoch 22/30
# 33/33 - 0s - 7ms/step - loss: 4.3701e-04 - mae: 0.0132 - val_loss: 4.3363e-04 - val_mae: 0.0131
# Epoch 23/30
# 33/33 - 0s - 7ms/step - loss: 4.3193e-04 - mae: 0.0131 - val_loss: 4.3299e-04 - val_mae: 0.0132
# Epoch 24/30
# 33/33 - 0s - 7ms/step - loss: 4.3087e-04 - mae: 0.0131 - val_loss: 4.2459e-04 - val_mae: 0.0129
# Epoch 25/30
# 33/33 - 0s - 7ms/step - loss: 4.2318e-04 - mae: 0.0129 - val_loss: 4.2273e-04 - val_mae: 0.0129
# Epoch 26/30
# 33/33 - 0s - 7ms/step - loss: 4.1602e-04 - mae: 0.0128 - val_loss: 4.1441e-04 - val_mae: 0.0127
# Epoch 27/30
# 33/33 - 0s - 7ms/step - loss: 4.1240e-04 - mae: 0.0127 - val_loss: 4.1547e-04 - val_mae: 0.0128
# Epoch 28/30
# 33/33 - 0s - 6ms/step - loss: 4.0626e-04 - mae: 0.0126 - val_loss: 4.1266e-04 - val_mae: 0.0127
# Epoch 29/30
# 33/33 - 0s - 7ms/step - loss: 4.0276e-04 - mae: 0.0126 - val_loss: 4.0061e-04 - val_mae: 0.0125
# Epoch 30/30
# 33/33 - 0s - 7ms/step - loss: 3.9461e-04 - mae: 0.0124 - val_loss: 3.9795e-04 - val_mae: 0.0125

# %%
recon_train = autoencoder.predict(X_train_norm)
mse_train = np.mean(np.power(X_train_norm - recon_train, 2), axis=1)
threshold = np.percentile(mse_train, 95)

recon_test = autoencoder.predict(X_test)
mse_test = np.mean(np.power(X_test - recon_test, 2), axis=1)
y_pred = (mse_test > threshold).astype(int)  # 1 indicates anomaly
# Out:
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
reconstructions_norm = autoencoder.predict(X_test_norm)
reconstructions_abn  = autoencoder.predict(X_test_abn)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
mse_norm = np.mean(np.power(X_test_norm - reconstructions_norm, 2), axis=1)
mse_abn  = np.mean(np.power(X_test_abn - reconstructions_abn, 2), axis=1)

# %%
plt.figure(figsize=(8, 5))
plt.hist(mse_norm, bins=50, alpha=0.6, label='Normal (MSE)', density=True)
plt.hist(mse_abn, bins=50, alpha=0.6, label='Abnormal (MSE)', density=True)

plt.title('Reconstruction Error Distribution')
plt.xlabel('Mean Squared Error')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
import seaborn as sns
sns.lineplot((history.history['loss'], history.history['mae']))
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report, confusion_matrix
print("Threshold:", threshold)
print(confusion_matrix(y_test.astype(int)==0, y_pred))  # abnormal vs predicted
print(classification_report(y_test.astype(int)==0, y_pred))
# Out:
# Threshold: 0.0010097733510391364
# [[562  29]
#  [  3 406]]
#               precision    recall  f1-score   support
#
#        False       0.99      0.95      0.97       591
#         True       0.93      0.99      0.96       409
#
#     accuracy                           0.97      1000
#    macro avg       0.96      0.97      0.97      1000
# weighted avg       0.97      0.97      0.97      1000

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
